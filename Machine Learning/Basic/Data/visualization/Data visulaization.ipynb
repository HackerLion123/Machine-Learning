# %% [markdown]
# # Data Visulization
# Basic data visulization using pyplot,seaborn.Dataset used here is no-show appoinment dataset from kaggle.

# %%
# No Show Appoinments



import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('KaggleV2-May-2016.csv')
data.head(20)
# Out:
#        PatientId  AppointmentID Gender          ScheduledDay  \
# 0   2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1   5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2   4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3   8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4   8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5   9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6   7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7   3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8   5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9   7.812456e+13        5629123      F  2016-04-27T12:48:25Z
# 10  7.345362e+14        5630213      F  2016-04-27T14:58:11Z
# 11  7.542951e+12        5620163      M  2016-04-26T08:44:12Z
# 12  5.666548e+14        5634718      F  2016-04-28T11:33:51Z
# 13  9.113946e+14        5636249      M  2016-04-28T14:52:07Z
# ...

# %%
no_show = (data['No-show'] == 'Yes')
# no_show.plot(figsize=(15,15))
# fig = plt.figure()
# no_show.plot(kind='bar')
data['Neighbourhood'].value_counts().head(5)

# %%
data['Gender'].value_counts().plot(kind='bar')

# %%
# available styles
print(plt.style.available)
# Out:
# ['seaborn-bright', 'seaborn-colorblind', 'ggplot', 'fast', 'seaborn-paper', 'tableau-colorblind10', 'fivethirtyeight', 'seaborn-pastel', 'Solarize_Light2', 'seaborn-ticks', '_classic_test', 'seaborn-dark-palette', 'seaborn-whitegrid', 'seaborn', 'dark_background', 'seaborn-muted', 'seaborn-talk', 'seaborn-darkgrid', 'seaborn-poster', 'seaborn-deep', 'seaborn-notebook', 'seaborn-white', 'classic', 'seaborn-dark', 'bmh', 'grayscale']

# %%
# %matplotlib inline
data.loc[(data['Gender'] == 'F' or ) & (data['Age']<25) & (data['Hipertension'] == 1),['Gender','Age','Hipertension']]
# Out:
#        Gender  Age  Hipertension
# 3647        F   17             1
# 5561        F    8             1
# 6425        F   22             1
# 6659        F   23             1
# 6943        F   13             1
# 10870       F   22             1
# 14149       F   19             1
# 22153       F   24             1
# 22677       F   23             1
# 22796       F   21             1
# 25138       F   14             1
# 25200       F   21             1
# 27127       F   19             1
# 33968       F   21             1
# 34075       F   24             1
# 36754       F   17             1
# 36854       F   14             1
# 36857       F   14             1
# 40226       F   22             1
# 41406       F   21             1
# 41760       F   16             1
# 41762       F   16             1
# 48111       F   23             1
# 49115       F   15             1
# 49449       F   23             1
# 52343       F   22             1
# 52823       F   20             1
# ...

# %%
pd.crosstab(data['No-show'],data['Gender'],margins=True)
# Out:
# Gender       F      M     All
# No-show
# No       57246  30962   88208
# Yes      14594   7725   22319
# All      71840  38687  110527

# %%
print(data[['Gender','Age']])
# Out:
#        Gender  Age
# 0           F   62
# 1           M   56
# 2           F   62
# 3           F    8
# 4           F   56
# 5           F   76
# 6           F   23
# 7           F   39
# 8           F   21
# 9           F   19
# 10          F   30
# 11          M   29
# 12          F   22
# 13          M   28
# 14          F   54
# 15          F   15
# 16          M   50
# 17          F   40
# 18          F   30
# 19          F   46
# 20          F   30
# 21          F    4
# 22          M   13
# 23          F   46
# 24          F   65
# 25          M   46
# 26          F   45
# 27          F    4
# 28          M   51
# 29          F   32
# ...       ...  ...
# 110497      M   76
# 110498      F   59
# 110499      F   66
# 110500      F   59
# 110501      M   44
# 110502      F   22
# 110503      F   64
# 110504      F    4
# 110505      F   55
# 110506      M    5
# 110507      F    0
# 110508      F   59
# 110509      M   33
# 110510      F   64
# 110511      F   14
# ...
